# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('products_final.csv', header=0,index_col=0)
df.head()
# Out:
#           brand                  name  price price_sign currency  \
# id
# 1048  colourpop         Lippie Pencil    5.0          $      CAD
# 1047  colourpop           Blotted Lip    5.5          $      CAD
# 1046  colourpop           Lippie Stix    5.5          $      CAD
# 1045  colourpop  No Filter Foundation   12.0          $      CAD
# 1044      boosh              Lipstick   26.0          $      CAD
#
#                                              image_link  \
# id
# 1048  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 1047  https://cdn.shopify.com/s/files/1/1338/0845/pr...
# 1046  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 1045  https://cdn.shopify.com/s/files/1/1338/0845/pr...
# 1044  https://cdn.shopify.com/s/files/1/1016/3243/pr...
#
#                                            product_link  \
# id
# 1048    https://colourpop.com/collections/lippie-pencil
# 1047  https://colourpop.com/collections/lippie-stix?...
# 1046      https://colourpop.com/collections/lippie-stix
# 1045  https://colourpop.com/products/no-filter-matte...
# 1044               https://www.boosh.ca/collections/all
#
#                                            website_link  \
# id
# 1048                              https://colourpop.com
# 1047                              https://colourpop.com
# 1046                              https://colourpop.com
# 1045  https://colourpop.com/products/no-filter-matte...
# 1044                              https://www.boosh.ca/
#
#                                             description  rating  ...  \
# id                                                               ...
# 1048  Lippie Pencil A long-wearing and high-intensit...     NaN  ...
# 1047  Blotted Lip Sheer matte lipstick that creates ...     NaN  ...
# 1046  Lippie Stix Formula contains Vitamin E, Mango,...     NaN  ...
# 1045  Developed for the Selfie Age, our buildable fu...     NaN  ...
# 1044  All of our products are free from lead and hea...     NaN  ...
#
#      product_colors/29/hex_value product_colors/29/colour_name  \
# id
# 1048                     #B5716A                  Brink Pencil
# 1047                         NaN                           NaN
# 1046                     #8F6557                        Tootsi
# 1045                     #C29879                      Dark 155
# 1044                         NaN                           NaN
#
#      product_colors/30/hex_value product_colors/30/colour_name  \
# id
# 1048                     #B0516F           I Heart This Pencil
# 1047                         NaN                           NaN
# 1046                     #AF7564                        Cookie
# 1045                     #B99179                      Dark 160
# 1044                         NaN                           NaN
#
#      product_colors/31/hex_value product_colors/31/colour_name  \
# id
# 1048                     #542328                Ellarie Pencil
# 1047                         NaN                           NaN
# 1046                     #AA4E79                    Persuasion
# 1045                     #C39981                      Dark 165
# 1044                         NaN                           NaN
#
#      product_colors/32/hex_value product_colors/32/colour_name  \
# id
# 1048                     #DFAC9B                    Toy Pencil
# 1047                         NaN                           NaN
# 1046                     #442A26                         Pitch
# 1045                     #B99078                      Dark 170
# 1044                         NaN                           NaN
#
#      product_colors/33/hex_value product_colors/33/colour_name
# id
# 1048                     #AB7164                  BFF Pencil 2
# 1047                         NaN                           NaN
# 1046                     #5C4761                       Leather
# 1045                     #B6927D                      Dark 175
# 1044                         NaN                           NaN
#
# [5 rows x 86 columns]

# %% [markdown]
# # Data exploration

# %%
df.dtypes
# Out:
# brand                             object
# name                              object
# price                            float64
# price_sign                        object
# currency                          object
#                                   ...
# product_colors/31/colour_name     object
# product_colors/32/hex_value       object
# product_colors/32/colour_name     object
# product_colors/33/hex_value       object
# product_colors/33/colour_name     object
# Length: 86, dtype: object

# %%
#information about each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 931 entries, 1048 to 1
# Data columns (total 86 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   brand                          919 non-null    object
#  1   name                           931 non-null    object
#  2   price                          917 non-null    float64
#  3   price_sign                     368 non-null    object
#  4   currency                       368 non-null    object
#  5   image_link                     931 non-null    object
#  6   product_link                   931 non-null    object
#  7   website_link                   931 non-null    object
#  8   description                    906 non-null    object
#  9   rating                         340 non-null    float64
#  10  category                       507 non-null    object
#  11  product_type                   931 non-null    object
#  12  tag_list/0/cruelty free        4 non-null      object
#  13  tag_list/1/Vegan               27 non-null     object
#  14  created_at                     931 non-null    object
#  15  updated_at                     931 non-null    object
#  16  product_api_url                931 non-null    object
#  17  api_featured_image             931 non-null    object
#  18  product_colors/0/hex_value     692 non-null    object
#  19  product_colors/0/colour_name   665 non-null    object
#  20  product_colors/1/hex_value     606 non-null    object
#  21  product_colors/1/colour_name   594 non-null    object
#  22  product_colors/2/hex_value     517 non-null    object
#  23  product_colors/2/colour_name   509 non-null    object
#  24  product_colors/3/hex_value     416 non-null    object
#  25  product_colors/3/colour_name   413 non-null    object
#  26  product_colors/4/hex_value     346 non-null    object
#  27  product_colors/4/colour_name   346 non-null    object
#  28  product_colors/5/hex_value     299 non-null    object
#  29  product_colors/5/colour_name   299 non-null    object
#  30  product_colors/6/hex_value     241 non-null    object
#  31  product_colors/6/colour_name   241 non-null    object
#  32  product_colors/7/hex_value     216 non-null    object
#  33  product_colors/7/colour_name   216 non-null    object
#  34  product_colors/8/hex_value     173 non-null    object
#  35  product_colors/8/colour_name   173 non-null    object
#  36  product_colors/9/hex_value     161 non-null    object
#  37  product_colors/9/colour_name   161 non-null    object
#  38  product_colors/10/hex_value    145 non-null    object
#  39  product_colors/10/colour_name  145 non-null    object
#  40  product_colors/11/hex_value    139 non-null    object
#  41  product_colors/11/colour_name  139 non-null    object
#  42  product_colors/12/hex_value    117 non-null    object
#  43  product_colors/12/colour_name  117 non-null    object
#  44  product_colors/13/hex_value    108 non-null    object
#  45  product_colors/13/colour_name  108 non-null    object
#  46  product_colors/14/hex_value    97 non-null     object
#  47  product_colors/14/colour_name  97 non-null     object
#  48  product_colors/15/hex_value    87 non-null     object
#  49  product_colors/15/colour_name  87 non-null     object
#  50  product_colors/16/hex_value    78 non-null     object
#  51  product_colors/16/colour_name  78 non-null     object
#  52  product_colors/17/hex_value    76 non-null     object
#  53  product_colors/17/colour_name  76 non-null     object
#  54  product_colors/18/hex_value    73 non-null     object
#  55  product_colors/18/colour_name  73 non-null     object
#  56  product_colors/19/hex_value    68 non-null     object
#  57  product_colors/19/colour_name  68 non-null     object
#  58  product_colors/20/hex_value    53 non-null     object
#  59  product_colors/20/colour_name  53 non-null     object
#  60  product_colors/21/hex_value    48 non-null     object
#  61  product_colors/21/colour_name  48 non-null     object
#  62  product_colors/22/hex_value    44 non-null     object
#  63  product_colors/22/colour_name  44 non-null     object
#  64  product_colors/23/hex_value    41 non-null     object
#  65  product_colors/23/colour_name  41 non-null     object
#  66  product_colors/24/hex_value    33 non-null     object
#  67  product_colors/24/colour_name  33 non-null     object
#  68  product_colors/25/hex_value    32 non-null     object
#  69  product_colors/25/colour_name  32 non-null     object
#  70  product_colors/26/hex_value    31 non-null     object
#  71  product_colors/26/colour_name  31 non-null     object
#  72  product_colors/27/hex_value    30 non-null     object
#  73  product_colors/27/colour_name  30 non-null     object
#  74  product_colors/28/hex_value    28 non-null     object
#  75  product_colors/28/colour_name  28 non-null     object
#  76  product_colors/29/hex_value    25 non-null     object
#  77  product_colors/29/colour_name  25 non-null     object
#  78  product_colors/30/hex_value    20 non-null     object
#  79  product_colors/30/colour_name  20 non-null     object
#  80  product_colors/31/hex_value    18 non-null     object
#  81  product_colors/31/colour_name  18 non-null     object
#  82  product_colors/32/hex_value    16 non-null     object
#  83  product_colors/32/colour_name  16 non-null     object
#  84  product_colors/33/hex_value    16 non-null     object
#  85  product_colors/33/colour_name  16 non-null     object
# dtypes: float64(2), object(84)
# memory usage: 632.8+ KB

# %%
df.shape
# Out:
# (931, 86)

# %%
df.columns
# Out:
# Index(['brand', 'name', 'price', 'price_sign', 'currency', 'image_link',
#        'product_link', 'website_link', 'description', 'rating', 'category',
#        'product_type', 'tag_list/0/cruelty free', 'tag_list/1/Vegan',
#        'created_at', 'updated_at', 'product_api_url', 'api_featured_image',
#        'product_colors/0/hex_value', 'product_colors/0/colour_name',
#        'product_colors/1/hex_value', 'product_colors/1/colour_name',
#        'product_colors/2/hex_value', 'product_colors/2/colour_name',
#        'product_colors/3/hex_value', 'product_colors/3/colour_name',
#        'product_colors/4/hex_value', 'product_colors/4/colour_name',
#        'product_colors/5/hex_value', 'product_colors/5/colour_name',
#        'product_colors/6/hex_value', 'product_colors/6/colour_name',
#        'product_colors/7/hex_value', 'product_colors/7/colour_name',
#        'product_colors/8/hex_value', 'product_colors/8/colour_name',
#        'product_colors/9/hex_value', 'product_colors/9/colour_name',
#        'product_colors/10/hex_value', 'product_colors/10/colour_name',
#        'product_colors/11/hex_value', 'product_colors/11/colour_name',
#        'product_colors/12/hex_value', 'product_colors/12/colour_name',
#        'product_colors/13/hex_value', 'product_colors/13/colour_name',
#        'product_colors/14/hex_value', 'product_colors/14/colour_name',
#        'product_colors/15/hex_value', 'product_colors/15/colour_name',
#        'product_colors/16/hex_value', 'product_colors/16/colour_name',
#        'product_colors/17/hex_value', 'product_colors/17/colour_name',
#        'product_colors/18/hex_value', 'product_colors/18/colour_name',
#        'product_colors/19/hex_value', 'product_colors/19/colour_name',
#        'product_colors/20/hex_value', 'product_colors/20/colour_name',
#        'product_colors/21/hex_value', 'product_colors/21/colour_name',
#        'product_colors/22/hex_value', 'product_colors/22/colour_name',
#        'product_colors/23/hex_value', 'product_colors/23/colour_name',
#        'product_colors/24/hex_value', 'product_colors/24/colour_name',
#        'product_colors/25/hex_value', 'product_colors/25/colour_name',
#        'product_colors/26/hex_value', 'product_colors/26/colour_name',
#        'product_colors/27/hex_value', 'product_colors/27/colour_name',
#        'product_colors/28/hex_value', 'product_colors/28/colour_name',
#        'product_colors/29/hex_value', 'product_colors/29/colour_name',
#        'product_colors/30/hex_value', 'product_colors/30/colour_name',
#        'product_colors/31/hex_value', 'product_colors/31/colour_name',
#        'product_colors/32/hex_value', 'product_colors/32/colour_name',
#        'product_colors/33/hex_value', 'product_colors/33/colour_name'],
#       dtype='object')

# %%
# delate diplicate rows
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# brand                             12
# name                               0
# price                             14
# price_sign                       563
# currency                         563
#                                 ...
# product_colors/31/colour_name    913
# product_colors/32/hex_value      915
# product_colors/32/colour_name    915
# product_colors/33/hex_value      915
# product_colors/33/colour_name    915
# Length: 86, dtype: int64

# %%
# observations with missing data
df[df.isnull().any(axis=1)].head()
# Out:
#           brand                  name  price price_sign currency  \
# id
# 1048  colourpop         Lippie Pencil    5.0          $      CAD
# 1047  colourpop           Blotted Lip    5.5          $      CAD
# 1046  colourpop           Lippie Stix    5.5          $      CAD
# 1045  colourpop  No Filter Foundation   12.0          $      CAD
# 1044      boosh              Lipstick   26.0          $      CAD
#
#                                              image_link  \
# id
# 1048  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 1047  https://cdn.shopify.com/s/files/1/1338/0845/pr...
# 1046  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 1045  https://cdn.shopify.com/s/files/1/1338/0845/pr...
# 1044  https://cdn.shopify.com/s/files/1/1016/3243/pr...
#
#                                            product_link  \
# id
# 1048    https://colourpop.com/collections/lippie-pencil
# 1047  https://colourpop.com/collections/lippie-stix?...
# 1046      https://colourpop.com/collections/lippie-stix
# 1045  https://colourpop.com/products/no-filter-matte...
# 1044               https://www.boosh.ca/collections/all
#
#                                            website_link  \
# id
# 1048                              https://colourpop.com
# 1047                              https://colourpop.com
# 1046                              https://colourpop.com
# 1045  https://colourpop.com/products/no-filter-matte...
# 1044                              https://www.boosh.ca/
#
#                                             description  rating  ...  \
# id                                                               ...
# 1048  Lippie Pencil A long-wearing and high-intensit...     NaN  ...
# 1047  Blotted Lip Sheer matte lipstick that creates ...     NaN  ...
# 1046  Lippie Stix Formula contains Vitamin E, Mango,...     NaN  ...
# 1045  Developed for the Selfie Age, our buildable fu...     NaN  ...
# 1044  All of our products are free from lead and hea...     NaN  ...
#
#      product_colors/29/hex_value product_colors/29/colour_name  \
# id
# 1048                     #B5716A                  Brink Pencil
# 1047                         NaN                           NaN
# 1046                     #8F6557                        Tootsi
# 1045                     #C29879                      Dark 155
# 1044                         NaN                           NaN
#
#      product_colors/30/hex_value product_colors/30/colour_name  \
# id
# 1048                     #B0516F           I Heart This Pencil
# 1047                         NaN                           NaN
# 1046                     #AF7564                        Cookie
# 1045                     #B99179                      Dark 160
# 1044                         NaN                           NaN
#
#      product_colors/31/hex_value product_colors/31/colour_name  \
# id
# 1048                     #542328                Ellarie Pencil
# 1047                         NaN                           NaN
# 1046                     #AA4E79                    Persuasion
# 1045                     #C39981                      Dark 165
# 1044                         NaN                           NaN
#
#      product_colors/32/hex_value product_colors/32/colour_name  \
# id
# 1048                     #DFAC9B                    Toy Pencil
# 1047                         NaN                           NaN
# 1046                     #442A26                         Pitch
# 1045                     #B99078                      Dark 170
# 1044                         NaN                           NaN
#
#      product_colors/33/hex_value product_colors/33/colour_name
# id
# 1048                     #AB7164                  BFF Pencil 2
# 1047                         NaN                           NaN
# 1046                     #5C4761                       Leather
# 1045                     #B6927D                      Dark 175
# 1044                         NaN                           NaN
#
# [5 rows x 86 columns]

# %%
df['category'].unique()
# Out:
# array(['pencil', 'lipstick', 'liquid', nan, 'powder', 'lip_gloss', 'gel',
#        'cream', 'palette', 'concealer', 'highlighter', 'bb_cc', 'contour',
#        'lip_stain', 'mineral'], dtype=object)

# %%
df['rating'].unique()
# Out:
# array([nan, 5. , 4. , 4.7, 4.5, 2.5, 4.6, 4.4, 3. , 3.8, 4.8, 3.3, 4.9,
#        4.3, 2. , 2.3, 4.2, 3.5, 3.7, 3.9, 4.1, 2.6, 3.6, 3.4, 1.5, 3.2,
#        3.1])

# %%
df['brand'].unique()
# Out:
# array(['colourpop', 'boosh', 'deciem', 'zorah biocosmetiques',
#        'w3llpeople', "sally b's skin yummies", 'rejuva minerals',
#        'penny lane organics', 'nudus', 'marienatie',
#        "maia's mineral galaxy", 'lotus cosmetics usa', 'green people',
#        'coastal classic creation', "c'est moi", 'alva', 'glossier', 'nyx',
#        'fenty', 'clinique', 'dior', 'iman', 'benefit', 'smashbox',
#        'marcelle', 'stila', 'mineral fusion', nan, 'annabelle',
#        'dr. hauschka', 'physicians formula', 'cargo cosmetics',
#        'covergirl', 'e.l.f.', 'maybelline', 'almay', 'milani',
#        'pure anada', "l'oreal", 'sante', 'revlon', 'anna sui',
#        'wet n wild', 'pacifica', 'mistura', 'zorah', 'suncoat', 'moov',
#        'misa', 'salon perfect', 'orly', 'china glaze', 'essie',
#        'butter london', 'sinful colours', 'piggy paint', 'dalish',
#        "burt's bees"], dtype=object)

# %%
df['product_type'].unique()
# Out:
# array(['lip_liner', 'lipstick', 'foundation', 'eyeliner', 'eyeshadow',
#        'blush', 'bronzer', 'mascara', 'eyebrow', 'nail_polish'],
#       dtype=object)

# %%
df['tag_list/0/cruelty free'].unique()
#'tag_list/0/cruelty free', 'tag_list/1/Vegan',
# Out:
# array(['cruelty free', nan], dtype=object)

# %%
df['category'].value_counts()
# Out:
# lipstick       122
# liquid         117
# powder          68
# pencil          62
# cream           34
# palette         27
# lip_gloss       26
# concealer       19
# mineral         11
# bb_cc            9
# lip_stain        4
# gel              3
# contour          3
# highlighter      2
# Name: category, dtype: int64

# %%
df.category.value_counts().plot(kind='bar', title='Products category')
plt.show()

# %%
pd.value_counts(df['product_type'].values, sort=True)
# Out:
# foundation     166
# lipstick       154
# eyeliner       148
# mascara         92
# eyeshadow       86
# blush           78
# bronzer         69
# nail_polish     60
# eyebrow         49
# lip_liner       29
# dtype: int64

# %%
df.product_type.value_counts().plot(kind='bar', title='Products types')
plt.show()

# %%
df['product_type'].where(df['rating'] > 4).count()
# Out:
# 227

# %%
#Only numerica data:
df_two = df._get_numeric_data()
df_two.head()
# Out:
#       price  rating
# id
# 1048    5.0     NaN
# 1047    5.5     NaN
# 1046    5.5     NaN
# 1045   12.0     NaN
# 1044   26.0     NaN

# %%
df.head(2)
df.iloc[0:2,]
# Out:
#           brand           name  price price_sign currency  \
# id
# 1048  colourpop  Lippie Pencil    5.0          $      CAD
# 1047  colourpop    Blotted Lip    5.5          $      CAD
#
#                                              image_link  \
# id
# 1048  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 1047  https://cdn.shopify.com/s/files/1/1338/0845/pr...
#
#                                            product_link  \
# id
# 1048    https://colourpop.com/collections/lippie-pencil
# 1047  https://colourpop.com/collections/lippie-stix?...
#
#                website_link  \
# id
# 1048  https://colourpop.com
# 1047  https://colourpop.com
#
#                                             description  rating  ...  \
# id                                                               ...
# 1048  Lippie Pencil A long-wearing and high-intensit...     NaN  ...
# 1047  Blotted Lip Sheer matte lipstick that creates ...     NaN  ...
#
#      product_colors/29/hex_value product_colors/29/colour_name  \
# id
# 1048                     #B5716A                  Brink Pencil
# 1047                         NaN                           NaN
#
#      product_colors/30/hex_value product_colors/30/colour_name  \
# id
# 1048                     #B0516F           I Heart This Pencil
# 1047                         NaN                           NaN
#
#      product_colors/31/hex_value product_colors/31/colour_name  \
# id
# 1048                     #542328                Ellarie Pencil
# 1047                         NaN                           NaN
#
#      product_colors/32/hex_value product_colors/32/colour_name  \
# id
# 1048                     #DFAC9B                    Toy Pencil
# 1047                         NaN                           NaN
#
#      product_colors/33/hex_value product_colors/33/colour_name
# id
# 1048                     #AB7164                  BFF Pencil 2
# 1047                         NaN                           NaN
#
# [2 rows x 86 columns]

# %%
# last three observations
df.iloc[-3:,]
# Out:
#                  brand                                               name  \
# id
# 3   physicians formula  Physicians Formula Organic Wear Lash Boosting ...
# 2                  NaN                  L' Oreal Paris Voluminous Mascara
# 1           pure anada                         Pure Anada Natural Mascara
#
#     price price_sign currency  \
# id
# 3   15.79        NaN      NaN
# 2    9.99        NaN      NaN
# 1   14.00        NaN      NaN
#
#                                            image_link  \
# id
# 3   https://d3t32hsnjxo7q6.cloudfront.net/i/ca3136...
# 2   https://d3t32hsnjxo7q6.cloudfront.net/i/4d671a...
# 1   https://d3t32hsnjxo7q6.cloudfront.net/i/afefed...
#
#                                          product_link     website_link  \
# id
# 3   https://well.ca/products/physicians-formula-or...  https://well.ca
# 2   https://well.ca/products/l-oreal-paris-volumin...  https://well.ca
# 1   https://well.ca/products/pure-anada-natural-ma...  https://well.ca
#
#                                           description  rating  ...  \
# id                                                             ...
# 3   Physicians Formula Organic Wear Lash Boosting ...     3.7  ...
# 2   Voluminous - Volume Building Waterproof Mascar...     4.5  ...
# 1   Finally, a natural mascara you can feel good a...     4.6  ...
#
#    product_colors/29/hex_value product_colors/29/colour_name  \
# id
# 3                          NaN                           NaN
# 2                          NaN                           NaN
# 1                          NaN                           NaN
#
#    product_colors/30/hex_value product_colors/30/colour_name  \
# id
# 3                          NaN                           NaN
# 2                          NaN                           NaN
# 1                          NaN                           NaN
#
#    product_colors/31/hex_value product_colors/31/colour_name  \
# id
# 3                          NaN                           NaN
# 2                          NaN                           NaN
# 1                          NaN                           NaN
#
#    product_colors/32/hex_value product_colors/32/colour_name  \
# id
# 3                          NaN                           NaN
# 2                          NaN                           NaN
# 1                          NaN                           NaN
#
#    product_colors/33/hex_value product_colors/33/colour_name
# id
# 3                          NaN                           NaN
# 2                          NaN                           NaN
# 1                          NaN                           NaN
#
# [3 rows x 86 columns]

# %%
#Selecting specific data from columns:
df.loc[3, ["brand", "category", "price", "rating", "product_type"]]
# Out:
# brand           physicians formula
# category                       NaN
# price                        15.79
# rating                         3.7
# product_type               mascara
# Name: 3, dtype: object

# %%
df.loc[[4, 5], ["brand","category", "price", "rating", "product_type"]]
# Out:
#                  brand category  price  rating product_type
# id
# 4   physicians formula      NaN  15.79     3.9      mascara
# 5             pacifica      NaN  28.00     4.2      mascara

# %%
df2 = df.loc[:, ["brand","category", "price", "rating", "product_type"]]
df2.head()
# Out:
#           brand  category  price  rating product_type
# id
# 1048  colourpop    pencil    5.0     NaN    lip_liner
# 1047  colourpop  lipstick    5.5     NaN     lipstick
# 1046  colourpop  lipstick    5.5     NaN     lipstick
# 1045  colourpop    liquid   12.0     NaN   foundation
# 1044      boosh  lipstick   26.0     NaN     lipstick

# %%
df2.loc[df2['brand'] == 'covergirl'].head()
# Out:
#          brand category  price  rating product_type
# id
# 499  covergirl      NaN  13.99     NaN      bronzer
# 486  covergirl      NaN   8.99     5.0      bronzer
# 473  covergirl   powder  13.99     NaN        blush
# 465  covergirl   powder  13.99     5.0        blush
# 458  covergirl   powder   8.99     5.0        blush

# %%
#Price greater than 50:

df2[df2['price'] > 50]
# Out:
#         brand  category  price  rating product_type
# id
# 697      dior   palette  65.00     NaN    eyeshadow
# 662      dior  lipstick  77.00     NaN     lipstick
# 639   benefit       NaN  75.00     NaN      bronzer
# 529  smashbox       NaN  55.00     NaN      eyebrow
# 527  smashbox   palette  52.00     NaN    eyeshadow
# 428     stila     cream  51.00     NaN        blush
# 427     stila     cream  51.00     NaN        blush
# 287   mistura       NaN  56.49     2.6    eyeshadow
# 274  pacifica       NaN  60.00     4.9      bronzer

# %%
#Rating greater than 4.0 and price greater than 20:

df2[(df2['rating'] > 4.0) & (df2['price'] > 20)].head()
# Out:
#                   brand category  price  rating product_type
# id
# 493  physicians formula      NaN  20.99     4.7      bronzer
# 490                 NaN      NaN  24.00     5.0      bronzer
# 489     cargo cosmetics      NaN  29.00     5.0      bronzer
# 483        dr. hauschka      NaN  45.00     4.6      bronzer
# 471     cargo cosmetics      NaN  36.00     5.0      bronzer

# %%
#Rating greater than 4.5 and price less than 10:

df2[(df2['rating'] > 4.5) & (df2['price'] < 10)].head()
# Out:
#          brand category  price  rating product_type
# id
# 486  covergirl      NaN   8.99     5.0      bronzer
# 458  covergirl   powder   8.99     5.0        blush
# 455  covergirl   powder   6.99     5.0        blush
# 449  covergirl   powder   6.99     5.0        blush
# 441     e.l.f.   powder   9.99     4.7        blush

# %%
#Observations where the rating between 1 and 3:

df2[df2['rating'].between(1,3)].head()
# Out:
#                   brand category  price  rating product_type
# id
# 484  physicians formula      NaN  21.99     2.5      bronzer
# 467               sante   powder  23.49     3.0        blush
# 420                 nyx    cream   9.99     2.0        blush
# 416                 NaN    cream  15.00     2.3        blush
# 403            marcelle      NaN  10.99     3.0    lip_liner

# %% [markdown]
# # Summary statistics

# %%
df2.describe()
# Out:
#             price      rating
# count  917.000000  340.000000
# mean    16.508593    4.319118
# std     11.028035    0.675849
# min      0.000000    1.500000
# 25%      8.990000    4.000000
# 50%     13.990000    4.500000
# 75%     22.000000    5.000000
# max     77.000000    5.000000

# %%
df2['price'].mean()
# Out:
# 16.508593238822208

# %%
# mean price for each rating 
df2.groupby('rating').mean()
# Out:
#             price
# rating
# 1.5     10.000000
# 2.0     12.990000
# 2.3     15.000000
# 2.5     13.906667
# 2.6     56.490000
# 3.0     13.603846
# 3.1     15.790000
# 3.2     15.790000
# 3.3     11.592000
# 3.4     15.872500
# 3.5     12.756667
# 3.6     28.000000
# 3.7      9.750000
# 3.8     15.257778
# 3.9     13.672000
# 4.0     13.905849
# 4.1     16.376667
# 4.2     12.090833
# 4.3     12.101304
# 4.4     13.404667
# 4.5     11.694828
# 4.6     16.169231
# 4.7     15.362353
# 4.8     16.197619
# 4.9     31.096000
# 5.0     14.031860

# %%
#The distribution of data on charts:

df2['rating'].hist()
# Out:
# <AxesSubplot:>

# %%
df2['price'].hist()
# Out:
# <AxesSubplot:>

# %%
df2[df2['brand'] == 'nyx'].hist()
# Out:
# array([[<AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'rating'}>]], dtype=object)

# %%
#Corelation:
cor = df2[['rating', 'price']].corr()
sns.heatmap(cor, annot=True)
# Out:
# <AxesSubplot:>

# %%
#The mean price of selected products:
df2.loc[df2['brand'] == 'maybelline'].mean()
# Out:
# C:\Users\sushi\AppData\Local\Temp/ipykernel_4828/3420091329.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2.loc[df2['brand'] == 'maybelline'].mean()
# price     11.138148
# rating     4.082609
# dtype: float64

# %%
df2.loc[df2['category'] == 'lipstick'].mean()
# Out:
# C:\Users\sushi\AppData\Local\Temp/ipykernel_4828/4130858894.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2.loc[df2['category'] == 'lipstick'].mean()
# price     14.444050
# rating     4.464865
# dtype: float64

# %%
df2.groupby('product_type')[['price']].mean()
# Out:
#                   price
# product_type
# blush         17.155395
# bronzer       22.738841
# eyebrow       20.963542
# eyeliner      12.624014
# eyeshadow     17.978929
# foundation    20.672407
# lip_liner      9.859655
# lipstick      14.517647
# mascara       14.193596
# nail_polish   12.901500

# %%
df2.groupby('product_type')[['rating']].mean()
# Out:
#                 rating
# product_type
# blush         4.419444
# bronzer       4.608333
# eyebrow            NaN
# eyeliner      4.230189
# eyeshadow     4.392500
# foundation    4.218519
# lip_liner     4.363636
# lipstick      4.435000
# mascara       4.281633
# nail_polish   4.118182

# %%
#Data Aggregation
#Number of observations in the column:

df2.groupby('category').size()
# Out:
# category
# bb_cc            9
# concealer       19
# contour          3
# cream           34
# gel              3
# highlighter      2
# lip_gloss       26
# lip_stain        4
# lipstick       122
# liquid         117
# mineral         11
# palette         27
# pencil          62
# powder          68
# dtype: int64

# %%
df2.groupby('product_type')['price'].agg(['max', 'mean'])
# Out:
#                 max       mean
# product_type
# blush         51.00  17.155395
# bronzer       75.00  22.738841
# eyebrow       55.00  20.963542
# eyeliner      36.00  12.624014
# eyeshadow     65.00  17.978929
# foundation    49.00  20.672407
# lip_liner     20.49   9.859655
# lipstick      77.00  14.517647
# mascara       33.00  14.193596
# nail_polish   22.49  12.901500

# %%
df2.groupby('product_type')['price', 'rating'].agg(['max', 'mean'])
# Out:
# C:\Users\sushi\AppData\Local\Temp/ipykernel_4828/2821000836.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2.groupby('product_type')['price', 'rating'].agg(['max', 'mean'])
#               price            rating
#                 max       mean    max      mean
# product_type
# blush         51.00  17.155395    5.0  4.419444
# bronzer       75.00  22.738841    5.0  4.608333
# eyebrow       55.00  20.963542    NaN       NaN
# eyeliner      36.00  12.624014    5.0  4.230189
# eyeshadow     65.00  17.978929    5.0  4.392500
# foundation    49.00  20.672407    5.0  4.218519
# lip_liner     20.49   9.859655    5.0  4.363636
# lipstick      77.00  14.517647    5.0  4.435000
# mascara       33.00  14.193596    5.0  4.281633
# nail_polish   22.49  12.901500    5.0  4.118182

# %%
df2.groupby('product_type').agg({'price': [np.size, np.mean, np.max ]})
# Out:
#              price
#               size       mean   amax
# product_type
# blush           78  17.155395  51.00
# bronzer         69  22.738841  75.00
# eyebrow         49  20.963542  55.00
# eyeliner       148  12.624014  36.00
# eyeshadow       86  17.978929  65.00
# foundation     166  20.672407  49.00
# lip_liner       29   9.859655  20.49
# lipstick       154  14.517647  77.00
# mascara         92  14.193596  33.00
# nail_polish     60  12.901500  22.49

# %%
df2.groupby('brand').count()[['product_type']]
# Out:
#                           product_type
# brand
# almay                               14
# alva                                 1
# anna sui                             6
# annabelle                           11
# benefit                             41
# boosh                                1
# burt's bees                          2
# butter london                        2
# c'est moi                            4
# cargo cosmetics                     20
# china glaze                          1
# clinique                            93
# coastal classic creation             1
# colourpop                            4
# covergirl                           54
# dalish                               1
# deciem                               2
# dior                                74
# dr. hauschka                        12
# e.l.f.                              27
# essie                                4
# fenty                                5
# glossier                             6
# green people                         1
# iman                                13
# l'oreal                             46
# lotus cosmetics usa                  7
# maia's mineral galaxy                1
# marcelle                            15
# marienatie                           9
# maybelline                          54
# milani                              13
# mineral fusion                       8
# misa                                 1
# mistura                              1
# moov                                 3
# nudus                                1
# nyx                                164
# orly                                 4
# pacifica                            13
# penny lane organics                  1
# physicians formula                  43
# piggy paint                          1
# pure anada                          16
# rejuva minerals                      6
# revlon                              29
# sally b's skin yummies               2
# salon perfect                        1
# sante                                6
# sinful colours                       1
# smashbox                            46
# stila                                4
# suncoat                              6
# w3llpeople                           1
# wet n wild                          12
# zorah                                2
# zorah biocosmetiques                 2

# %%
df2.groupby('brand').count()[['product_type']].plot(kind='bar',figsize=(15,5), color=['green'], title='The amount of products types by brand')
plt.show()

# %%
#Sorting
df2.sort_values(by='brand').head()
# Out:
#      brand category  price  rating product_type
# id
# 328  almay   liquid  17.29     4.5   foundation
# 45   almay      NaN  10.99     4.3      mascara
# 302  almay      NaN  10.99     4.5    eyeshadow
# 448  almay   powder  14.49     4.0        blush
# 314  almay      NaN  10.49     4.0    eyeshadow

# %%
df.sort_values(by='rating', ascending=False).head()
# Out:
#                   brand                                               name  \
# id
# 508                 nyx                   NYX Mosaic Powder Blush Paradise
# 201            marcelle        Marcelle Kajal Kohl Eyeliner Blackest Black
# 192  physicians formula  Physicians Formula Shimmer Strips Kohl Kajal E...
# 189  physicians formula  Physicians Formula Shimmer Strips Kohl Kajal E...
# 183              e.l.f.                        e.l.f. Intense Ink Eyeliner
#
#      price price_sign currency  \
# id
# 508  10.49        NaN      NaN
# 201  11.99        NaN      NaN
# 192  14.79        NaN      NaN
# 189  14.79        NaN      NaN
# 183   3.99        NaN      NaN
#
#                                             image_link  \
# id
# 508  https://d3t32hsnjxo7q6.cloudfront.net/i/deedb7...
# 201  https://d3t32hsnjxo7q6.cloudfront.net/i/bb7368...
# 192  https://d3t32hsnjxo7q6.cloudfront.net/i/ac56e1...
# 189  https://d3t32hsnjxo7q6.cloudfront.net/i/98c26c...
# 183  https://d3t32hsnjxo7q6.cloudfront.net/i/805d4c...
#
#                                           product_link     website_link  \
# id
# 508  https://well.ca/products/nyx-mosaic-powder-blu...  https://well.ca
# 201  https://well.ca/products/marcelle-kajal-kohl-e...  https://well.ca
# 192  https://well.ca/products/physicians-formula-sh...  https://well.ca
# 189  https://well.ca/products/physicians-formula-sh...  https://well.ca
# 183  https://well.ca/products/elf-intense-ink-eyeli...  https://well.ca
#
#                                            description  rating  ...  \
# id                                                              ...
# 508  NYX Mosaic Powder Blush is a medley of that cr...     5.0  ...
# 201  \n        Marcelle Kajal Kohl Eyeliner is offe...     5.0  ...
# 192  Physicians Formula's intense and richly pigmen...     5.0  ...
# 189  Physicians Formula Shimmer Strips Kohl Kajal E...     5.0  ...
# 183  e.l.f. Intense Ink Eyeliner quick-dry formula ...     5.0  ...
#
#     product_colors/29/hex_value product_colors/29/colour_name  \
# id
# 508                         NaN                           NaN
# 201                         NaN                           NaN
# 192                         NaN                           NaN
# 189                         NaN                           NaN
# 183                         NaN                           NaN
#
#     product_colors/30/hex_value product_colors/30/colour_name  \
# id
# 508                         NaN                           NaN
# 201                         NaN                           NaN
# 192                         NaN                           NaN
# 189                         NaN                           NaN
# 183                         NaN                           NaN
#
#     product_colors/31/hex_value product_colors/31/colour_name  \
# id
# 508                         NaN                           NaN
# 201                         NaN                           NaN
# 192                         NaN                           NaN
# 189                         NaN                           NaN
# 183                         NaN                           NaN
#
#     product_colors/32/hex_value product_colors/32/colour_name  \
# id
# 508                         NaN                           NaN
# 201                         NaN                           NaN
# 192                         NaN                           NaN
# 189                         NaN                           NaN
# 183                         NaN                           NaN
#
#     product_colors/33/hex_value product_colors/33/colour_name
# id
# 508                         NaN                           NaN
# 201                         NaN                           NaN
# 192                         NaN                           NaN
# 189                         NaN                           NaN
# 183                         NaN                           NaN
#
# [5 rows x 86 columns]

# %%
df2.groupby(['product_type'])[['price']].mean().sort_values('price', ascending=False)
# Out:
#                   price
# product_type
# bronzer       22.738841
# eyebrow       20.963542
# foundation    20.672407
# eyeshadow     17.978929
# blush         17.155395
# lipstick      14.517647
# mascara       14.193596
# nail_polish   12.901500
# eyeliner      12.624014
# lip_liner      9.859655

# %%
df2.groupby(['product_type'])[['price']].mean().sort_values('price', ascending=False).plot(kind='bar', 
                                                color=['violet'], title='The average price of each product type')
plt.show()

# %% [markdown]
# # Cleaning data

# %%
df.isna().sum()
# Out:
# brand                             12
# name                               0
# price                             14
# price_sign                       563
# currency                         563
#                                 ...
# product_colors/31/colour_name    913
# product_colors/32/hex_value      915
# product_colors/32/colour_name    915
# product_colors/33/hex_value      915
# product_colors/33/colour_name    915
# Length: 86, dtype: int64

# %%
# delate unnecessary columns
df_new= df.drop(['category','currency', 'description', 'price_sign'], axis=1)
df_new.head()
# Out:
#           brand                  name  price  \
# id
# 1048  colourpop         Lippie Pencil    5.0
# 1047  colourpop           Blotted Lip    5.5
# 1046  colourpop           Lippie Stix    5.5
# 1045  colourpop  No Filter Foundation   12.0
# 1044      boosh              Lipstick   26.0
#
#                                              image_link  \
# id
# 1048  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 1047  https://cdn.shopify.com/s/files/1/1338/0845/pr...
# 1046  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 1045  https://cdn.shopify.com/s/files/1/1338/0845/pr...
# 1044  https://cdn.shopify.com/s/files/1/1016/3243/pr...
#
#                                            product_link  \
# id
# 1048    https://colourpop.com/collections/lippie-pencil
# 1047  https://colourpop.com/collections/lippie-stix?...
# 1046      https://colourpop.com/collections/lippie-stix
# 1045  https://colourpop.com/products/no-filter-matte...
# 1044               https://www.boosh.ca/collections/all
#
#                                            website_link  rating product_type  \
# id
# 1048                              https://colourpop.com     NaN    lip_liner
# 1047                              https://colourpop.com     NaN     lipstick
# 1046                              https://colourpop.com     NaN     lipstick
# 1045  https://colourpop.com/products/no-filter-matte...     NaN   foundation
# 1044                              https://www.boosh.ca/     NaN     lipstick
#
#      tag_list/0/cruelty free tag_list/1/Vegan  ...  \
# id                                             ...
# 1048            cruelty free            Vegan  ...
# 1047            cruelty free            Vegan  ...
# 1046            cruelty free            Vegan  ...
# 1045            cruelty free            Vegan  ...
# 1044                     NaN              NaN  ...
#
#      product_colors/29/hex_value product_colors/29/colour_name  \
# id
# 1048                     #B5716A                  Brink Pencil
# 1047                         NaN                           NaN
# 1046                     #8F6557                        Tootsi
# 1045                     #C29879                      Dark 155
# 1044                         NaN                           NaN
#
#      product_colors/30/hex_value product_colors/30/colour_name  \
# id
# 1048                     #B0516F           I Heart This Pencil
# 1047                         NaN                           NaN
# 1046                     #AF7564                        Cookie
# 1045                     #B99179                      Dark 160
# 1044                         NaN                           NaN
#
#      product_colors/31/hex_value product_colors/31/colour_name  \
# id
# 1048                     #542328                Ellarie Pencil
# 1047                         NaN                           NaN
# 1046                     #AA4E79                    Persuasion
# 1045                     #C39981                      Dark 165
# 1044                         NaN                           NaN
#
#      product_colors/32/hex_value product_colors/32/colour_name  \
# id
# 1048                     #DFAC9B                    Toy Pencil
# 1047                         NaN                           NaN
# 1046                     #442A26                         Pitch
# 1045                     #B99078                      Dark 170
# 1044                         NaN                           NaN
#
#      product_colors/33/hex_value product_colors/33/colour_name
# id
# 1048                     #AB7164                  BFF Pencil 2
# 1047                         NaN                           NaN
# 1046                     #5C4761                       Leather
# 1045                     #B6927D                      Dark 175
# 1044                         NaN                           NaN
#
# [5 rows x 82 columns]

# %%
#delate rows with missing data 
df_new.dropna(subset=['brand'], inplace=True)

# %% [markdown]
# # Completing missing values

# %%
mean_df = df_new['price'].mean()
mean_df
# Out:
# 16.448066298342507

# %%
df_new['price'] = df_new['price'].fillna(mean_df)

# %%
df_new['rating'] = df_new['rating'].fillna('0')

# %%
df_new['rating'].value_counts().sort_values(ascending=False)
# Out:
# 0      587
# 5.0     84
# 4.0     52
# 4.5     27
# 4.3     23
# 4.8     21
# 4.7     17
# 4.4     15
# 3.0     13
# 4.6     13
# 4.2     12
# 3.8      9
# 2.5      6
# 3.9      5
# 4.1      5
# 4.9      5
# 3.7      5
# 3.3      5
# 2.0      4
# 3.5      3
# 3.4      3
# 2.6      1
# 3.6      1
# 1.5      1
# 3.2      1
# 3.1      1
# Name: rating, dtype: int64

# %%
df_new['rating'].value_counts().sort_values(ascending=False).plot(kind='bar', color=['red'], title='Rating')
plt.show()

# %%
df_new.isnull().sum()
# Out:
# brand                              0
# name                               0
# price                              0
# image_link                         0
# product_link                       0
#                                 ...
# product_colors/31/colour_name    901
# product_colors/32/hex_value      903
# product_colors/32/colour_name    903
# product_colors/33/hex_value      903
# product_colors/33/colour_name    903
# Length: 82, dtype: int64

# %%
df = pd.read_csv('products_final.csv', header=0,index_col=0)
df.head()
# Out:
#           brand                  name  price price_sign currency  \
# id
# 1048  colourpop         Lippie Pencil    5.0          $      CAD
# 1047  colourpop           Blotted Lip    5.5          $      CAD
# 1046  colourpop           Lippie Stix    5.5          $      CAD
# 1045  colourpop  No Filter Foundation   12.0          $      CAD
# 1044      boosh              Lipstick   26.0          $      CAD
#
#                                              image_link  \
# id
# 1048  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 1047  https://cdn.shopify.com/s/files/1/1338/0845/pr...
# 1046  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 1045  https://cdn.shopify.com/s/files/1/1338/0845/pr...
# 1044  https://cdn.shopify.com/s/files/1/1016/3243/pr...
#
#                                            product_link  \
# id
# 1048    https://colourpop.com/collections/lippie-pencil
# 1047  https://colourpop.com/collections/lippie-stix?...
# 1046      https://colourpop.com/collections/lippie-stix
# 1045  https://colourpop.com/products/no-filter-matte...
# 1044               https://www.boosh.ca/collections/all
#
#                                            website_link  \
# id
# 1048                              https://colourpop.com
# 1047                              https://colourpop.com
# 1046                              https://colourpop.com
# 1045  https://colourpop.com/products/no-filter-matte...
# 1044                              https://www.boosh.ca/
#
#                                             description  rating  ...  \
# id                                                               ...
# 1048  Lippie Pencil A long-wearing and high-intensit...     NaN  ...
# 1047  Blotted Lip Sheer matte lipstick that creates ...     NaN  ...
# 1046  Lippie Stix Formula contains Vitamin E, Mango,...     NaN  ...
# 1045  Developed for the Selfie Age, our buildable fu...     NaN  ...
# 1044  All of our products are free from lead and hea...     NaN  ...
#
#      product_colors/29/hex_value product_colors/29/colour_name  \
# id
# 1048                     #B5716A                  Brink Pencil
# 1047                         NaN                           NaN
# 1046                     #8F6557                        Tootsi
# 1045                     #C29879                      Dark 155
# 1044                         NaN                           NaN
#
#      product_colors/30/hex_value product_colors/30/colour_name  \
# id
# 1048                     #B0516F           I Heart This Pencil
# 1047                         NaN                           NaN
# 1046                     #AF7564                        Cookie
# 1045                     #B99179                      Dark 160
# 1044                         NaN                           NaN
#
#      product_colors/31/hex_value product_colors/31/colour_name  \
# id
# 1048                     #542328                Ellarie Pencil
# 1047                         NaN                           NaN
# 1046                     #AA4E79                    Persuasion
# 1045                     #C39981                      Dark 165
# 1044                         NaN                           NaN
#
#      product_colors/32/hex_value product_colors/32/colour_name  \
# id
# 1048                     #DFAC9B                    Toy Pencil
# 1047                         NaN                           NaN
# 1046                     #442A26                         Pitch
# 1045                     #B99078                      Dark 170
# 1044                         NaN                           NaN
#
#      product_colors/33/hex_value product_colors/33/colour_name
# id
# 1048                     #AB7164                  BFF Pencil 2
# 1047                         NaN                           NaN
# 1046                     #5C4761                       Leather
# 1045                     #B6927D                      Dark 175
# 1044                         NaN                           NaN
#
# [5 rows x 86 columns]
